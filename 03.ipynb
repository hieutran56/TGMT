# %%
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/ADMIN/Desktop/WorkSpace/Anh/02.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x675>

# %%
#Kich thuoc ban dau
print(img.size)
# Out:
# (1200, 675)

# %%
#Tao kich thuoc moi
new_size=(600,600)

# %%
new_image = img.resize(new_size)
display(new_image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 new_image = img.resize(new_size)
#       2 display(new_image)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\PIL\Image.py:2183, in Image.resize(self, size, resample, box, reducing_gap)
#    2180     msg = "reducing_gap must be 1.0 or greater"
#    2181     raise ValueError(msg)
# -> 2183 size = tuple(size)
#    2185 self.load()
#    2186 if box is None:
#
# TypeError: 'int' object is not iterable
